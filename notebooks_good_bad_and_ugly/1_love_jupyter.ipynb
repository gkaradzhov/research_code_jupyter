# %% [markdown]
# # Basic python

# %%
# Running code
results = [1, 1, 2, 3]
print(max(results))
# Out:
# 3

# %%
min_value = min(results)
max_value = max(results)
range_values = max_value - min_value

# %%
range_values
# Out:
# 2

# %%
scaled = [(r - min_value)/range_values for r in results]

# %%
scaled
# Out:
# [0.0, 0.0, 0.5, 1.0]

# %% [markdown]
# # Executing bash commands

# %%
# !pip3 freeze
# Out:
# appnope==0.1.0
# attrs==19.1.0
# backcall==0.1.0
# bleach==3.1.0
# certifi==2019.3.9
# chardet==3.0.4
# cycler==0.10.0
# decorator==4.3.2
# defusedxml==0.5.0
# entrypoints==0.3
# idna==2.8
# ipykernel==5.1.0
# ipympl==0.2.1
# ipython==7.3.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# jedi==0.13.3
# Jinja2==2.10
# jsonschema==3.0.1
# jupyter==1.0.0
# jupyter-client==5.2.4
# jupyter-console==6.0.0
# jupyter-core==4.4.0
# jupyterlab==0.35.4
# jupyterlab-server==0.2.0
# kiwisolver==1.0.1
# MarkupSafe==1.1.1
# matplotlib==3.0.3
# mistune==0.8.4
# nbconvert==5.4.1
# nbformat==4.4.0
# notebook==5.7.6
# numpy==1.16.2
# pandas==0.24.1
# pandocfilters==1.4.2
# parso==0.3.4
# pexpect==4.6.0
# pickleshare==0.7.5
# pkg-resources==0.0.0
# plotly==3.7.0
# prometheus-client==0.6.0
# prompt-toolkit==2.0.9
# ptyprocess==0.6.0
# Pygments==2.3.1
# pyparsing==2.3.1
# pyrsistent==0.14.11
# python-dateutil==2.8.0
# pytz==2018.9
# pyzmq==18.0.1
# qgrid==1.1.1
# qtconsole==4.4.3
# requests==2.21.0
# retrying==1.3.3
# scipy==1.2.1
# seaborn==0.9.0
# Send2Trash==1.5.0
# six==1.12.0
# terminado==0.8.1
# testpath==0.4.2
# tornado==6.0.1
# traitlets==4.3.2
# urllib3==1.24.1
# wcwidth==0.1.7
# webencodings==0.5.1
# widgetsnbextension==3.4.2
# You are using pip version 8.1.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
! head README.md
# Out:
# head: cannot open 'README.md' for reading: No such file or directory

# %% [markdown]
# # Jupyter Magics

# %%
# %time [(r - min_value)/range_values for r in results]
# Out:
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 9.06 µs
# [0.0, 0.0, 0.5, 1.0]

# %% [markdown]
# # Rich text format

# %% [markdown]
# ## LaTeX !!

# %% [markdown]
# %%latex
# \begin{align}
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$

# %% [markdown]
# ## Free text + images

# %% [markdown]
# Supports markdown syntax:
# - lists
# - headings
# - links

# %% [markdown]
# ![Image of Yaktocat](https://upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Jupiter_and_its_shrunken_Great_Red_Spot.jpg/220px-Jupiter_and_its_shrunken_Great_Red_Spot.jpg)

# %% [markdown]
# # Manipulate data

# %%
import qgrid
import pandas as pd

# %%
df = pd.read_csv('../test_data.csv')

# %%
qwidget = qgrid.show_grid(df)
qwidget
# Out:
# QgridWidget(grid_options={'boldIndex': True, 'maxVisibleRows': 15, 'defaultColumnWidth': 150, 'rowHeight': 28,…

# %% [markdown]
# # Data Visualisation

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/zoo/zoo.data -O zoo.data
# %ls
# Out:
# --2019-06-17 20:20:04--  https://archive.ics.uci.edu/ml/machine-learning-databases/zoo/zoo.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4126 (4.0K) [application/x-httpd-php]
# Saving to: ‘zoo.data’
#
# zoo.data            100%[===================>]   4.03K  --.-KB/s    in 0s
#
# 2019-06-17 20:20:05 (8.22 MB/s) - ‘zoo.data’ saved [4126/4126]
#
# 1_love_jupyter.ipynb     3_buggy_notebook.ipynb  5_sanity_checks.ipynb
# 2_research_python.ipynb  4_unittests.ipynb       zoo.data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
column_names = ["hair", "feathers", "eggs", "milk", "airborne", "aquatic", 
                "predator", "toothed", "backbone", "breathes", "venomous", 
                "fins", "legs", "tail", "domestic", "catsize", "type"]

zoo_data = pd.read_csv('zoo.data', names=column_names)

# %%
zoo_data.head()
# Out:
#           hair  feathers  eggs  milk  airborne  aquatic  predator  toothed  \
# aardvark     1         0     0     1         0        0         1        1
# antelope     1         0     0     1         0        0         0        1
# bass         0         0     1     0         0        1         1        1
# bear         1         0     0     1         0        0         1        1
# boar         1         0     0     1         0        0         1        1
#
#           backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# aardvark         1         1         0     0     4     0         0        1
# antelope         1         1         0     0     4     1         0        1
# bass             1         0         0     1     0     1         0        0
# bear             1         1         0     0     4     0         0        1
# boar             1         1         0     0     4     1         0        1
#
#           type
# aardvark     1
# antelope     1
# bass         4
# bear         1
# boar         1

# %%
correlation_matrix = zoo_data.corr()
plt.figure(figsize=(20,14))
sns.heatmap(correlation_matrix, cbar=True,  square=True, annot=True,annot_kws={'size': 12}, linewidths=0.15, linecolor='white')
plt.title('Correlation of ZOO Features', y=1.05, size=15)
# Out:
# Text(0.5, 1.05, 'Correlation of ZOO Features')
